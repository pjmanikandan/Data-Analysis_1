# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # 1-Replace the NaN values with correct values .And Justify why you have chosen the same

# %%
#1/ Central Tendency ,2/Full Row remove our dataset,3/ Cluster method to find what type in our NaN value

#our dataset have 67 missing value so filling missing value replace "0" because our salary column missing
#67 value represend non placed student so using nan value replace "0" not affected our data

# %%
dataset["salary"].fillna(0,inplace = True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # 2-How many of them are not placed

# %%
dataset["status"].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
dataset["status"].value_counts()["Not Placed"]
# Out:
# 67

# %% [markdown]
# # 3-Find the reason for non placement from the dataset

# %%
nonp=dataset[dataset['status'] == 'Not Placed']

# %%
nonp
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
def quanQual(nonp):
    quan=[]
    qual=[]
    for columnName in nonp.columns:

        if(nonp[columnName].dtypes=='O'):
            qual.append(columnName)
        else:
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(nonp)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
 nonplaced=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for colname in quan:
    nonplaced[colname]["Mean"]=nonp[colname].mean()
    nonplaced[colname]["Median"]=nonp[colname].median()
    nonplaced[colname]["Mode"]=nonp[colname].mode()[0]

# %%
nonplaced
# Out:
#              sl_no     ssc_p      hsc_p   degree_p   etest_p      mba_p salary
# Mean    110.477612  57.54403  58.395522  61.134179  69.58791  61.612836    0.0
# Median       107.0     56.28      60.33       61.0      67.0      60.69    0.0
# Mode             4      52.0       62.0       65.0      60.0      51.21    0.0

# %%
plac=dataset[dataset['status'] == 'Placed']

# %%
plac
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
 placed=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for colname in quan:
    placed[colname]["Mean"]=plac[colname].mean()
    placed[colname]["Median"]=plac[colname].median()
    placed[colname]["Mode"]=plac[colname].mode()[0]

# %%
placed
# Out:
#              sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    106.878378  71.721486  69.926554  68.740541  73.238041  62.579392
# Median       108.5       72.5       68.0       68.0       72.0     62.245
# Mode             1       73.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# # ("placed" -Mean,Median > "nonplaced"-Mean,Median ) ssc_p,hsc_p,degree_p,etest_p,mba_p Marks are "placed" > "nonplaced"  thats the reason student are nonplaced.

# %% [markdown]
# # 4-What kind of relation between salary and mba_p

# %%
  plac.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432  0.063764
# ssc_p    -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560  0.035330
# hsc_p    -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983  0.076819
# degree_p -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093 -0.019272
# etest_p   0.041467  0.317892  0.284672  0.217683  1.000000  0.284143  0.178307
# mba_p    -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# # 0.175013 that is 17% of positive relation b/w salary and mba_p

# %% [markdown]
# # 5-Which specialization is getting minimum salary

# %%
plac["specialisation"].value_counts()
# Out:
# Mkt&Fin    95
# Mkt&HR     53
# Name: specialisation, dtype: int64

# %%
plac.sort_values(["salary"], ascending = True)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 163    164      M  63.00   Others  67.00   Others   Science     64.00
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 150    151      M  71.00  Central  58.66  Central   Science     58.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %% [markdown]
# # both Mkt&HR and  Mkt&Fin have same  min salary starting salary is 200000

# %% [markdown]
# # 6-How many of them getting above 500000 salary

# %%
above=plac[plac["salary"]>500000]

# %%
above
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %% [markdown]
# # three members only get  above "500000" salary ,(sl_no=120,151,178)

# %% [markdown]
# # 7-Test the Analysis of variance between etest_p and mba_p at significance level 5% (Make decision using Hypothesis testing )

# %%
#total dataset(with non placed student)
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#placed student only
import scipy.stats as stats
stats.f_oneway(plac["etest_p"],plac["mba_p"])
# Out:
# F_onewayResult(statistic=75.35669909200762, pvalue=2.7511196898832345e-16)

# %% [markdown]
# # P<0.05
# #Ho-There is no significant variance  between this columns.
# #H1-There is significant varaiabce  between this columns.
# #Reject Ho
# #Accept H1.
#
#
# #TThere is significant varaiabce  between this columns.

# %% [markdown]
# # 8-Test the similarity between the degree_t(Sci&Tech) and specialization(Mkt&HR) with respect to salary at significant level of 5%(Make decision using Hypothesis testing)

# %% [markdown]
# degree_t(Sci&Tech) and specialization(Mkt&HR) with respect to salary
#
# different category but same condition
#
# Unpaired - T Test

# %%
from scipy.stats import ttest_ind
degree=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
speci=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]

ttest_ind(degree,speci)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %%
from scipy.stats import ttest_ind
degree=plac[plac["degree_t"]=="Sci&Tech"]["salary"]
speci=plac[plac["specialisation"]=="Mkt&HR"]["salary"]

ttest_ind(degree,speci)
# Out:
# Ttest_indResult(statistic=2.734391160944239, pvalue=0.007496896218767113)

# %% [markdown]
# P<0.05
# #Ho-There is no similarity between those columns.
# #H1-There is similarity between those columns.
# #Accept Ho
# #Reject H1.
#
# #There is no similarity between those columns.

# %% [markdown]
# # 9-Convert the normal distribution to standardnormal distribution for salary columns

# %%
import seaborn as sns

# %%
sns.distplot(dataset["salary"])
# Out:
# C:\Users\PJ MANI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %% [markdown]
# # 10-What is the probability Density Function of the salary range from 700000 to 900000

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'Green'},color='blue')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    sample=dataset
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f , Standard Deviation=%.3f' % (sample_mean, sample_std))
    dist=norm(sample_mean,sample_std)
    values=[value for value  in range (startrange,endrange)]
    probabilities=[dist.pdf(values) for values in values] 
    prob=sum(probabilities)
    print ("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
#with non placed student
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\PJ MANI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Mean=198702.326 , Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974901
# 0.0005973310593974901

# %%
#placed student only
get_pdf_probability(plac["salary"],700000,900000)
# Out:
# C:\Users\PJ MANI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Mean=288655.405 , Standard Deviation=93457.452
# The area between range(700000,900000):5.377578376230696e-06
# 5.377578376230696e-06

# %% [markdown]
# # 11-Test the similarity between the degree_t(sci&Tech) with respect to etest_p and mba_p at significance level of 5%(Make decision using Hypothesis Testing)

# %% [markdown]
# Dependent sample-paird T Test
# same group(male)but different condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_ind
degree1=dataset[dataset["degree_t"]=="Sci&Tech"]["etest_p"]
degree2=dataset[dataset["degree_t"]=="Sci&Tech"]["mba_p"]
ttest_ind(degree1,degree2)
# Out:
# Ttest_indResult(statistic=4.532000225151251, pvalue=1.4289217003775636e-05)

# %%
from scipy.stats import ttest_ind
degree1=plac[plac["degree_t"]=="Sci&Tech"]["etest_p"]
degree2=plac[plac["degree_t"]=="Sci&Tech"]["mba_p"]
ttest_ind(degree1,degree2)
# Out:
# Ttest_indResult(statistic=4.286330847883897, pvalue=5.0277529026696514e-05)

# %%
# Ho-There is no similarity b/w etest_p and mba_p in degree_t(sci&Tech) sig level of 0.05
#H1-There is similarity b/w etest_p and mba_p in degree_t(sci&Tech) sig level of 0.05
#Reject Ho
#Accept H1

#There is similarity b/w etest_p and mba_p in degree_t(sci&Tech)

# %% [markdown]
# # 12-Which parameter is highly correlated with salary

# %%
#placed student only
plac.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432  0.063764
# ssc_p    -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560  0.035330
# hsc_p    -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983  0.076819
# degree_p -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093 -0.019272
# etest_p   0.041467  0.317892  0.284672  0.217683  1.000000  0.284143  0.178307
# mba_p    -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# etest_p,mba_p is highly correlated with salary 17%

# %%
#with non placed student
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# ssc_p is highly correlated with salary  54%

# %% [markdown]
# # 13-Plot any useful graph and explain

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
#only placed student
sns.pairplot(plac)
